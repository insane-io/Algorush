# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha-singh2207/Algorush/blob/main/Ridge%20and%20Lasso%20Regularisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/load_boston_final_lyst1729240745225.csv")

# %%
df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
# ...

# %%
x=df.iloc[:,1:14]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
# sacling so that the different scales of the dataset entries become available
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score

c_v = cross_val_score(lr, x_train, y_train, scoring='neg_mean_squared_error', cv=10)
c_v_1=cross_val_score(lr,x_train,y_train,scoring='neg_mean_absolute_error',cv=10)

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([32.3914647 , 27.94401279, 17.83762764, 21.66941388, 18.93639614,
#        20.01995795, 32.63414961, 17.86179976, 24.73211676, 26.77346826,
#        27.26138023, 28.63243014, 21.16103038, 27.15098589, 23.33198614,
#        21.02894005, 17.11819755, 37.52455938, 30.69864427,  8.46104486,
#        20.83966032, 16.26732451, 25.05030307, 24.8069032 , 31.6789299 ,
#        10.98989363, 13.54111562, 16.54697099, 35.86699683, 14.69589266,
#        21.05655107, 13.90301353, 43.01321262, 17.80335305, 21.68817023,
#        20.45077825, 17.38095983, 26.81334904, 10.08706217, 19.96174586,
#        24.1983249 , 21.00202622, 29.38682967, 16.33215467, 19.37439646,
#        14.45525235, 39.52670798, 18.18535021, 26.38536303, 20.41420863,
#        25.08511581, 24.40208165, 24.87902769, 26.97887956,  4.93921657,
#        24.0001365 , 10.66711602, 26.98494775, 16.63507993, 35.31652989,
#        19.49249915, 27.37577863, 16.53965715, 19.09746715, 11.06765336,
# ...

# %%
lr.score(x_train,y_train)
# Out:
# 0.7103879080674731

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 3.344665503598748
# 19.831323672063125

# %%
c_v
# Out:
# array([-25.3373018 , -42.11726715, -18.46383118, -22.14831964,
#        -11.06355679, -38.46957076, -31.90922818, -23.61549677,
#        -35.01490246, -11.48471174])

# %%
c_v.mean()
# Out:
# np.float64(-25.962418646515268)

# %%
c_v_1
# Out:
# array([-3.36732003, -3.8057665 , -3.51448772, -3.6123696 , -2.74309418,
#        -3.92318398, -4.00595995, -3.79490414, -3.74690383, -2.63939323])

# %%
c_v_1.mean()
# Out:
# np.float64(-3.5153383166373224)

# %% [markdown]
# Ridge regularisation

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
ridge_1=Ridge()

# %%
parameters={"alpha":[1,2,3,4,5,6,7,10,30,40,50,70,45]}
ridge_cv=GridSearchCV(ridge_1,parameters,scoring="neg_mean_squared_error",cv=10)
ridge_cv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': [1, 2, 3, 4, 5, 6, 7, 10, 30, 40, 50, 70,
#                                    45]},
#              scoring='neg_mean_squared_error')

# %%
ridge_cv.best_params_
# Out:
# {'alpha': 5}

# %%
ridge_pred=ridge_cv.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(ridge_pred,y_test,)
# Out:
# 0.6389787837027225

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7836295385076293

# %% [markdown]
# Lasso Regression model:

# %%
from sklearn.linear_model import Lasso

# %%
lasso_l=Lasso()

# %%
parameters={"alpha":[1,2,3,4,5,6,7,10,30,40,50,70,45]}
lasso_cv = GridSearchCV(lasso_l, parameters, scoring="neg_mean_squared_error", cv=5)
lasso_cv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1, 2, 3, 4, 5, 6, 7, 10, 30, 40, 50, 70,
#                                    45]},
#              scoring='neg_mean_squared_error')

# %%
lasso_pred=lasso_cv.predict(x_test)

# %%
r2_score(y_test,lasso_pred)
# Out:
# 0.6738812929458313
